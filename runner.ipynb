# %% [markdown]
# ## Training Step

# %%
from google.colab import drive
import os
drive.mount('/content/drive')

print(os.listdir('/content/drive/MyDrive/DL2')) ## change to your folder
os.chdir('/content/drive/MyDrive/DL2')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['readme.md', 'data', 'figures', 'scripts', 'output', 'runner.ipynb']

# %%
os.listdir('.')
# Out:
# ['readme.md', 'data', 'figures', 'scripts', 'output', 'runner.ipynb']

# %%
# !pip install torchmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# #### Baseline - Classification

# %%
# %run scripts/train.py --det_root "data/mini-coco-det/images/train" --det_ann "data/mini-coco-det/annotations/instances_train.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/train" --epoch 30 --batchsize 16 --lr 1e-4 --train_type cls
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %% [markdown]
# #### Baseline - Segmentation

# %%
# %run scripts/train.py --det_root "data/mini-coco-det/images/train" --det_ann "data/mini-coco-det/annotations/instances_train.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/train" --epoch 30 --batchsize 16 --lr 1e-4 --train_type seg
# Out:
# ...
# Epoch 10: 100%|██████████| 15/15 [00:10<00:00,  1.48it/s, task=seg, loss=0.865]
# 0.34628745913505554
# {'mIoU': 0.34628745913505554}
# mIoU: 0.34628745913505554
# Epoch 11: 100%|██████████| 15/15 [00:10<00:00,  1.48it/s, task=seg, loss=0.707]
# 0.3580612242221832
# {'mIoU': 0.3580612242221832}
# mIoU: 0.3580612242221832
# Epoch 12: 100%|██████████| 15/15 [00:10<00:00,  1.45it/s, task=seg, loss=0.758]
# 0.3643059730529785
# {'mIoU': 0.3643059730529785}
# mIoU: 0.3643059730529785
# Epoch 13: 100%|██████████| 15/15 [00:11<00:00,  1.33it/s, task=seg, loss=0.656]
# 0.37047097086906433
# {'mIoU': 0.37047097086906433}
# mIoU: 0.37047097086906433
# Epoch 14: 100%|██████████| 15/15 [00:10<00:00,  1.39it/s, task=seg, loss=0.749]
# 0.36548423767089844
# {'mIoU': 0.36548423767089844}
# mIoU: 0.36548423767089844
# Epoch 15: 100%|██████████| 15/15 [00:10<00:00,  1.47it/s, task=seg, loss=0.546]
# 0.3842993974685669
# {'mIoU': 0.3842993974685669}
# mIoU: 0.3842993974685669
# ...

# %% [markdown]
# #### Baseline - Detection

# %%
# %run scripts/train.py --det_root "data/mini-coco-det/images/train" --det_ann "data/mini-coco-det/annotations/instances_train.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/train" --epoch 30 --batchsize 12 --lr 1e-4 --train_type det
# Out:
# loading annotations into memory...
# Done (t=0.56s)
# creating index...
# index created!
# ...
# Epoch 10: 100%|██████████| 20/20 [00:09<00:00,  2.21it/s, task=det, loss=0.0281]
# loading annotations into memory...
# Done (t=0.87s)
# creating index...
# index created!
#   0%|          | 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Encountered more than 100 detections in a single image. This means that certain detections with the lowest scores will be ignored, that may have an undesirable impact on performance. Please consider adjusting the `max_detection_threshold` to suit your use case. To disable this warning, set attribute class `warn_on_many_detections=False`, after initializing the metric.
#   warnings.warn(*args, **kwargs)
# {'mAP': tensor(0.0038)}
# mAP: 0.003773871110752225
# Epoch 11: 100%|██████████| 20/20 [00:08<00:00,  2.24it/s, task=det, loss=0.0271]
# loading annotations into memory...
# Done (t=1.17s)
# ...

# %% [markdown]
# #### Unified Model Training

# %%
# %run scripts/train.py --det_root "data/mini-coco-det/images/train" --det_ann "data/mini-coco-det/annotations/instances_train.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/train" --epoch 50 --batchsize 4 --lr 3e-4 --lambda_distill 2 --train_type "all" --teacher
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %% [markdown]
# ## Testing

# %%
## baseline on classification
# %run scripts/test.py --det_root "data/mini-coco-det/images/test" --det_ann "data/mini-coco-det/annotations/instances_test.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/test" --task cls --ckpt 'output/cls_best.pth'
## baseline on segmentation
# %run scripts/test.py --det_root "data/mini-coco-det/images/test" --det_ann "data/mini-coco-det/annotations/instances_test.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/test" --task seg --ckpt 'output/seg_best.pth'
## baseline on detection
# %run scripts/test.py --det_root "data/mini-coco-det/images/test" --det_ann "data/mini-coco-det/annotations/instances_test.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/test" --task det --ckpt 'output/det_best.pth'
## test all on classification
# %run scripts/test.py --det_root "data/mini-coco-det/images/test" --det_ann "data/mini-coco-det/annotations/instances_test.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/test" --task cls --ckpt 'output/all_best.pth'
## test all on segmentation
# %run scripts/test.py --det_root "data/mini-coco-det/images/test" --det_ann "data/mini-coco-det/annotations/instances_test.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/test" --task seg --ckpt 'output/all_best.pth'
## test all on detection
# %run scripts/test.py --det_root "data/mini-coco-det/images/test" --det_ann "data/mini-coco-det/annotations/instances_test.json" --seg_root "data/mini-voc-seg" --cls_root "data/imagenette-160/test" --task det --ckpt 'output/all_best.pth'
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
